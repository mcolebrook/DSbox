# %% [markdown]
# # Testing R kernel

# %%
.libPaths(c(file.path(Sys.getenv("SPARK_HOME"), "R", "lib"), .libPaths()))

# %%
.libPaths()
# Out:
# [1] "/opt/spark-1.5.2-bin-hadoop2.6/R/lib"
# [2] "/usr/local/lib/R/site-library"
# [3] "/usr/lib/R/site-library"
# [4] "/usr/lib/R/library"

# %%
Sys.getenv("SPARK_HOME")
# Out:
# [1] "/opt/spark"

# %%
library(SparkR)
sc <- sparkR.init(master="local")
# Out:
# Attaching package: ‘SparkR’
#
# The following objects are masked from ‘package:stats’:
#
#     filter, na.omit
#
# The following objects are masked from ‘package:base’:
#
#     intersect, rbind, sample, subset, summary, table, transform
# Launching java with spark-submit command /opt/spark/bin/spark-submit   sparkr-shell /tmp/RtmpEUjT9Z/backend_port6c95804d8d5

# %%
installed.packages()
# Out:
#            Package      LibPath                                Version
# SparkR     "SparkR"     "/opt/spark-1.5.2-bin-hadoop2.6/R/lib" "1.5.2"
# base64enc  "base64enc"  "/usr/local/lib/R/site-library"        "0.1-3"
# digest     "digest"     "/usr/local/lib/R/site-library"        "0.6.8"
# evaluate   "evaluate"   "/usr/local/lib/R/site-library"        "0.8"
# IRdisplay  "IRdisplay"  "/usr/local/lib/R/site-library"        "0.3"
# IRkernel   "IRkernel"   "/usr/local/lib/R/site-library"        "0.5"
# jsonlite   "jsonlite"   "/usr/local/lib/R/site-library"        "0.9.19"
# magrittr   "magrittr"   "/usr/local/lib/R/site-library"        "1.5"
# repr       "repr"       "/usr/local/lib/R/site-library"        "0.4"
# rzmq       "rzmq"       "/usr/local/lib/R/site-library"        "0.7.7"
# stringi    "stringi"    "/usr/local/lib/R/site-library"        "1.0-1"
# stringr    "stringr"    "/usr/local/lib/R/site-library"        "1.0.0"
# uuid       "uuid"       "/usr/local/lib/R/site-library"        "0.1-2"
# base       "base"       "/usr/lib/R/library"                   "3.2.3"
# boot       "boot"       "/usr/lib/R/library"                   "1.3-17"
# class      "class"      "/usr/lib/R/library"                   "7.3-14"
# cluster    "cluster"    "/usr/lib/R/library"                   "2.0.3"
# codetools  "codetools"  "/usr/lib/R/library"                   "0.2-14"
# compiler   "compiler"   "/usr/lib/R/library"                   "3.2.3"
# datasets   "datasets"   "/usr/lib/R/library"                   "3.2.3"
# foreign    "foreign"    "/usr/lib/R/library"                   "0.8-66"
# graphics   "graphics"   "/usr/lib/R/library"                   "3.2.3"
# grDevices  "grDevices"  "/usr/lib/R/library"                   "3.2.3"
# grid       "grid"       "/usr/lib/R/library"                   "3.2.3"
# KernSmooth "KernSmooth" "/usr/lib/R/library"                   "2.23-15"
# lattice    "lattice"    "/usr/lib/R/library"                   "0.20-33"
# MASS       "MASS"       "/usr/lib/R/library"                   "7.3-44"
# Matrix     "Matrix"     "/usr/lib/R/library"                   "1.2-3"
# methods    "methods"    "/usr/lib/R/library"                   "3.2.3"
# mgcv       "mgcv"       "/usr/lib/R/library"                   "1.8-7"
# nlme       "nlme"       "/usr/lib/R/library"                   "3.1-122"
# nnet       "nnet"       "/usr/lib/R/library"                   "7.3-11"
# parallel   "parallel"   "/usr/lib/R/library"                   "3.2.3"
# rpart      "rpart"      "/usr/lib/R/library"                   "4.1-10"
# spatial    "spatial"    "/usr/lib/R/library"                   "7.3-10"
# splines    "splines"    "/usr/lib/R/library"                   "3.2.3"
# stats      "stats"      "/usr/lib/R/library"                   "3.2.3"
# stats4     "stats4"     "/usr/lib/R/library"                   "3.2.3"
# survival   "survival"   "/usr/lib/R/library"                   "2.38-3"
# tcltk      "tcltk"      "/usr/lib/R/library"                   "3.2.3"
# tools      "tools"      "/usr/lib/R/library"                   "3.2.3"
# utils      "utils"      "/usr/lib/R/library"                   "3.2.3"
#            Priority      Depends
# SparkR     NA            "\nR (>= 3.0),\nmethods,"
# base64enc  NA            "R (>= 2.9.0)"
# digest     NA            "R (>= 2.4.1)"
# evaluate   NA            "R (>= 3.0.2)"
# IRdisplay  NA            "R (>= 3.0.1)"
# IRkernel   NA            "R (>= 3.0.1)"
# jsonlite   NA            "methods"
# magrittr   NA            NA
# repr       NA            "R (>= 3.0.1)"
# rzmq       NA            NA
# stringi    NA            "R (>= 2.13.1)"
# stringr    NA            "R (>= 2.14)"
# uuid       NA            "R (>= 2.9.0)"
# base       "base"        NA
# boot       "recommended" "R (>= 3.0.0), graphics, stats"
# class      "recommended" "R (>= 3.0.0), stats, utils"
# cluster    "recommended" "R (>= 2.15.0), utils"
# codetools  "recommended" "R (>= 2.1)"
# compiler   "base"        NA
# datasets   "base"        NA
# foreign    "recommended" "R (>= 3.0.0)"
# graphics   "base"        NA
# grDevices  "base"        NA
# grid       "base"        NA
# KernSmooth "recommended" "R (>= 2.5.0), stats"
# lattice    "recommended" "R (>= 3.0.0)"
# MASS       "recommended" "R (>= 3.1.0), grDevices, graphics, stats, utils"
# Matrix     "recommended" "R (>= 3.0.1)"
# methods    "base"        NA
# mgcv       "recommended" "R (>= 2.14.0), nlme (>= 3.1-64)"
# nlme       "recommended" "graphics, stats, R (>= 3.0.0)"
# nnet       "recommended" "R (>= 2.14.0), stats, utils"
# parallel   "base"        NA
# rpart      "recommended" "R (>= 2.15.0), graphics, stats, grDevices"
# spatial    "recommended" "R (>= 3.0.0), graphics, stats, utils"
# splines    "base"        NA
# stats      "base"        NA
# stats4     "base"        NA
# survival   "recommended" "R (>= 2.13.0), graphics, stats"
# tcltk      "base"        NA
# tools      "base"        NA
# utils      "base"        NA
#            Imports
# SparkR     "\nmethods"
# base64enc  NA
# digest     NA
# evaluate   "methods, stringr (>= 0.6.2)"
# IRdisplay  "repr, base64enc"
# IRkernel   "repr, methods, evaluate (>= 0.5.4), IRdisplay, rzmq (>=\n0.7.0), jsonlite (>= 0.9.6), uuid, digest"
# jsonlite   NA
# magrittr   NA
# repr       NA
# rzmq       NA
# stringi    "tools, utils, stats"
# stringr    "stringi (>= 0.4.1), magrittr"
# uuid       NA
# base       NA
# boot       NA
# class      "MASS"
# cluster    "graphics, grDevices, stats"
# codetools  NA
# compiler   NA
# datasets   NA
# foreign    "methods, utils, stats"
# graphics   "grDevices"
# grDevices  NA
# grid       "grDevices"
# KernSmooth NA
# lattice    "grid, grDevices, graphics, stats, utils"
# MASS       "methods"
# Matrix     "methods, graphics, grid, stats, utils, lattice"
# methods    "utils"
# mgcv       "methods, stats, graphics, Matrix"
# nlme       "lattice"
# nnet       NA
# parallel   "tools"
# rpart      NA
# spatial    NA
# splines    "graphics, stats"
# stats      NA
# stats4     "graphics, methods, stats"
# survival   "splines, methods"
# tcltk      "utils"
# tools      NA
# utils      NA
#            LinkingTo Suggests
# SparkR     NA        "\ntestthat"
# base64enc  NA        NA
# digest     NA        NA
# evaluate   NA        "testthat, lattice, ggplot2"
# IRdisplay  NA        NA
# IRkernel   NA        NA
# jsonlite   NA        "curl (>= 0.5), plyr, testthat, knitr, rmarkdown, R.rsp"
# magrittr   NA        "testthat, knitr"
# repr       NA        "highr"
# rzmq       NA        NA
# stringi    NA        NA
# stringr    NA        "testthat, knitr"
# uuid       NA        NA
# base       NA        "methods"
# boot       NA        "MASS, survival"
# class      NA        NA
# cluster    NA        "MASS"
# codetools  NA        NA
# compiler   NA        NA
# datasets   NA        NA
# foreign    NA        NA
# graphics   NA        NA
# grDevices  NA        "KernSmooth"
# grid       NA        "lattice"
# KernSmooth NA        "MASS"
# lattice    NA        "KernSmooth, MASS"
# MASS       NA        "lattice, nlme, nnet, survival"
# Matrix     NA        "expm, MASS"
# methods    NA        "codetools"
# mgcv       NA        "splines, parallel, survival, MASS"
# nlme       NA        "Hmisc, MASS"
# nnet       NA        "MASS"
# parallel   NA        "methods"
# rpart      NA        "survival"
# spatial    NA        "MASS"
# splines    NA        "Matrix, methods"
# stats      NA        "MASS, Matrix, SuppDists, methods, stats4"
# stats4     NA        NA
# survival   NA        "cmprsk"
# tcltk      NA        NA
# tools      NA        "XML, codetools, methods"
# utils      NA        "methods"
#            Enhances                                License
# SparkR     NA                                      "Apache License (== 2.0)"
# base64enc  "png"                                   "GPL-2 | GPL-3"
# digest     NA                                      "GPL-2"
# evaluate   NA                                      "MIT + file LICENSE"
# IRdisplay  NA                                      "MIT + file LICENSE"
# IRkernel   NA                                      "MIT + file LICENSE"
# jsonlite   NA                                      "MIT + file LICENSE"
# magrittr   NA                                      "MIT + file LICENSE"
# repr       NA                                      "GPL-3"
# rzmq       NA                                      "GPL-3"
# stringi    NA                                      "file LICENSE"
# stringr    NA                                      "GPL-2"
# uuid       NA                                      "MIT + file LICENSE"
# base       NA                                      "Part of R 3.2.3"
# boot       NA                                      "Unlimited"
# class      NA                                      "GPL-2 | GPL-3"
# cluster    NA                                      "GPL (>= 2)"
# codetools  NA                                      "GPL"
# compiler   NA                                      "Part of R 3.2.3"
# datasets   NA                                      "Part of R 3.2.3"
# foreign    NA                                      "GPL (>= 2)"
# graphics   NA                                      "Part of R 3.2.3"
# grDevices  NA                                      "Part of R 3.2.3"
# grid       NA                                      "Part of R 3.2.3"
# KernSmooth NA                                      "Unlimited"
# lattice    "chron"                                 "GPL (>= 2)"
# MASS       NA                                      "GPL-2 | GPL-3"
# Matrix     "MatrixModels, graph, SparseM, sfsmisc" "GPL (>= 2)"
# methods    NA                                      "Part of R 3.2.3"
# mgcv       NA                                      "GPL (>= 2)"
# nlme       NA                                      "GPL (>= 2)"
# nnet       NA                                      "GPL-2 | GPL-3"
# parallel   "snow, nws, Rmpi"                       "Part of R 3.2.3"
# rpart      NA                                      "GPL-2 | GPL-3"
# spatial    NA                                      "GPL-2 | GPL-3"
# splines    NA                                      "Part of R 3.2.3"
# stats      NA                                      "Part of R 3.2.3"
# stats4     NA                                      "Part of R 3.2.3"
# survival   NA                                      "LGPL (>= 2)"
# tcltk      NA                                      "Part of R 3.2.3"
# tools      NA                                      "Part of R 3.2.3"
# utils      NA                                      "Part of R 3.2.3"
#            License_is_FOSS License_restricts_use OS_type MD5sum
# SparkR     NA              NA                    NA      NA
# base64enc  NA              NA                    NA      NA
# digest     NA              NA                    NA      NA
# evaluate   NA              NA                    NA      NA
# IRdisplay  NA              NA                    NA      NA
# IRkernel   NA              NA                    NA      NA
# jsonlite   NA              NA                    NA      NA
# magrittr   NA              NA                    NA      NA
# repr       NA              NA                    NA      NA
# rzmq       NA              NA                    NA      NA
# stringi    "yes"           NA                    NA      NA
# stringr    NA              NA                    NA      NA
# uuid       NA              NA                    NA      NA
# base       NA              NA                    NA      NA
# boot       NA              NA                    NA      NA
# class      NA              NA                    NA      NA
# cluster    NA              NA                    NA      NA
# codetools  NA              NA                    NA      NA
# compiler   NA              NA                    NA      NA
# datasets   NA              NA                    NA      NA
# foreign    NA              NA                    NA      NA
# graphics   NA              NA                    NA      NA
# grDevices  NA              NA                    NA      NA
# grid       NA              NA                    NA      NA
# KernSmooth NA              NA                    NA      NA
# lattice    NA              NA                    NA      NA
# MASS       NA              NA                    NA      NA
# Matrix     NA              NA                    NA      NA
# methods    NA              NA                    NA      NA
# mgcv       NA              NA                    NA      NA
# nlme       NA              NA                    NA      NA
# nnet       NA              NA                    NA      NA
# parallel   NA              NA                    NA      NA
# rpart      NA              NA                    NA      NA
# spatial    NA              NA                    NA      NA
# splines    NA              NA                    NA      NA
# stats      NA              NA                    NA      NA
# stats4     NA              NA                    NA      NA
# survival   NA              NA                    NA      NA
# tcltk      NA              NA                    NA      NA
# tools      NA              NA                    NA      NA
# utils      NA              NA                    NA      NA
#            NeedsCompilation Built
# SparkR     NA               "3.2.1"
# base64enc  "yes"            "3.2.3"
# digest     "yes"            "3.2.3"
# evaluate   "no"             "3.2.3"
# IRdisplay  "no"             "3.2.3"
# IRkernel   "no"             "3.2.3"
# jsonlite   "yes"            "3.2.3"
# magrittr   "no"             "3.2.3"
# repr       "no"             "3.2.3"
# rzmq       "yes"            "3.2.3"
# stringi    "yes"            "3.2.3"
# stringr    "no"             "3.2.3"
# uuid       "yes"            "3.2.3"
# base       NA               "3.2.3"
# boot       "no"             "3.2.1"
# class      "yes"            "3.2.2"
# cluster    "yes"            "3.2.1"
# codetools  "no"             "3.2.2"
# compiler   NA               "3.2.3"
# datasets   NA               "3.2.3"
# foreign    "yes"            "3.2.2"
# graphics   NA               "3.2.3"
# grDevices  NA               "3.2.3"
# grid       NA               "3.2.3"
# KernSmooth "yes"            "3.2.1"
# lattice    "yes"            "3.2.1"
# MASS       "yes"            "3.2.2"
# Matrix     "yes"            "3.2.2"
# methods    NA               "3.2.3"
# mgcv       "yes"            "3.2.1"
# nlme       "yes"            "3.2.2"
# nnet       "yes"            "3.2.2"
# parallel   NA               "3.2.3"
# rpart      "yes"            "3.2.1"
# spatial    "yes"            "3.2.2"
# splines    NA               "3.2.3"
# stats      NA               "3.2.3"
# stats4     NA               "3.2.3"
# survival   "yes"            "3.2.1"
# tcltk      NA               "3.2.3"
# tools      NA               "3.2.3"
# utils      NA               "3.2.3"

# %%
library("stats")

# %%
x <- mean(2:50)

# %%
x
# Out:
# [1] 26
